# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.studyblue.com/notes/note/n/petrobowl-questions-part-1/deck/13481356'
req = requests.get(url)
html_data = req.text
soup = BeautifulSoup(html_data,'html.parser')

# %%
data = []
for div in soup.findAll('div',{'class':'text text-small'}): 
    data = np.append(data,div.text)

# %%
data = np.insert(data,[614,978,1061,1085],[' ']*4)
data = data.reshape((-1,2))
data = pd.DataFrame(data,columns=['Question','Answer'])

# %%
data.to_csv('StudyBlue_PetroBowl.csv')

# %%
data
# Out:
#                                               Question  \
# 0                 Who is the CEO of Chesapeake Energy?
# 1            What are 5 assumptions behind Darcy flow?
# 2                           Who is the CEO of Chevron?
# 3    Which oil company has the highest oil production?
# 4                        Top 5 oil producing companies
# 5                List current total world oil reserves
# 6                           Founder and CEO of Hilcorp
# 7          What is the formula for effective porosity?
# 8    Which country has the largest amount of natura...
# 9                        Top 5 oil producing countries
# 10         Formula for rate during exponential decline
# 11              Who invented the earliest form of ESP?
# 12   To what state did Arutunoff relocate his ESP p...
# 13   Where was the first successful ESP implementat...
# 14              Who was the first woman SPE president?
# 15                      How many countries are in SPE?
# ...
